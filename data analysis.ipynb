# %%
'''1. Import the dataset and write a description about the dataset.
2. Find the count of the missing values and describe how you have handled the missing data.
3. Univariate Analysis - Plot the univariate graphs and find the outliers.Explain how you have handled the outliers by transformation (optional).
4. Bivariate Analysis - Plot the bivariate graphs and find the relationship between the variables. Explain your findings and inference of the graphs.

5. Multivariate Analysis - Plot the multivariate graphs and find the relationship between the variables. Explain your findings and inference of the graphs. 
NOTE: Univariate, Bivariate and Multivariate analysis must contain total 15 visualisations or more.
    
6. Final Plots – Select 3 most interesting graphs from the above analysis and describe why those graphs are chosen.'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
shark=pd.read_csv("C:\\Users\\acer\\Desktop\\machine\\shark_tank.csv")

# %%
shark.head()
# Out:
#     deal                                        description  episode  \
# 0  False             Bluetooth device implant for your ear.        1
# 1   True  Retail and wholesale pie factory with two reta...        1
# 2   True  Ava the Elephant is a godsend for frazzled par...        1
# 3  False  Organizing, packing, and moving services deliv...        1
# 4  False  Interactive media centers for healthcare waiti...        1
#
#               category                entrepreneurs      location  \
# 0            Novelties               Darrin Johnson  St. Paul, MN
# 1       Specialty Food                   Tod Wilson  Somerset, NJ
# 2  Baby and Child Care              Tiffany Krumins   Atlanta, GA
# 3    Consumer Services  Nick Friedman, Omar Soliman     Tampa, FL
# 4    Consumer Services               Kevin Flannery      Cary, NC
#
#                                website  askedFor  exchangeForStake  valuation  \
# ...

# %%
shark.describe()
# Out:
#           episode      askedFor  exchangeForStake     valuation      season
# count  495.000000  4.950000e+02        495.000000  4.950000e+02  495.000000
# mean    12.125253  2.584909e+05         17.539394  2.165615e+06    4.048485
# std      7.918133  4.615999e+05         10.061047  3.761971e+06    1.658518
# min      1.000000  1.000000e+04          3.000000  4.000000e+04    1.000000
# 25%      5.000000  7.500000e+04         10.000000  4.400000e+05    3.000000
# 50%     11.000000  1.500000e+05         15.000000  1.000000e+06    4.000000
# 75%     18.000000  2.500000e+05         20.000000  2.000000e+06    5.000000
# max     29.000000  5.000000e+06        100.000000  3.000000e+07    6.000000

# %%
'''2. Find the count of the missing values and describe how you have handled the missing data.'''

# %%
shark.isnull().sum()
# Out:
# deal                       0
# description                0
# episode                    0
# category                   0
# entrepreneurs             72
# location                   0
# website                   38
# askedFor                   0
# exchangeForStake           0
# valuation                  0
# season                     0
# shark1                     0
# shark2                     0
# shark3                     0
# shark4                     0
# shark5                     0
# title                      0
# episode-season             0
# Multiple Entreprenuers     0
# dtype: int64

# %%
shark.shape
# Out:
# (495, 19)

# %%
shark.dropna(inplace=True)

# %%
shark.head(10)
# Out:
#      deal                                        description  episode  \
# 1    True  Retail and wholesale pie factory with two reta...        1
# 2    True  Ava the Elephant is a godsend for frazzled par...        1
# 3   False  Organizing, packing, and moving services deliv...        1
# 4   False  Interactive media centers for healthcare waiti...        1
# 5    True  One of the first entrepreneurs to pitch on Sha...        2
# 6   False  A mixed martial arts clothing line looking to ...        2
# 7   False  Attach Noted is a detachable "arm" that holds ...        2
# 8   False  A safety device for seatbelts. It prevents the...        2
# 11  False  Household items with a twist: made from recycl...        3
# 12   True  A line of books written to help children find ...        3
#
#                    category                entrepreneurs         location  \
# 1            Specialty Food                   Tod Wilson     Somerset, NJ
# ...

# %%
shark.shape
# Out:
# (387, 19)

# %%
'''3. Univariate Analysis - Plot the univariate graphs and find the outliers.'''
# Out:
# '3. Univariate Analysis - Plot the univariate graphs and find the outliers.'

# %%
plt.plot(shark["askedFor"])
plt.ylabel("Price asked")
plt.xlabel("No. of entreprenuers")
# Out:
# Text(0.5,0,'No. of entreprenuers')

# %%
sns.distplot(shark["askedFor"],kde=True)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(100,40))
sns.countplot(shark["category"])

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=shark["valuation"])

# %%
plt.figure(figsize=(20,10))
sns.countplot(hue='deal',x='valuation',data=shark)

# %%
sns.jointplot(x='valuation',y='askedFor',data=shark)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\acer\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.lmplot(x='valuation',y='askedFor',data=shark)

# %%
sns.heatmap(shark.corr(),annot=True)

# %%
sns.pairplot(shark)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='deal',y='askedFor',data=shark)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='deal',y='valuation',data=shark)

# %%
plt.scatter(shark["episode"],shark["deal"])
plt.xlabel("episode")
plt.ylabel("deal")
plt.show()

# %%
plt.scatter(shark["episode"],shark["season"])
plt.xlabel("episode")
plt.ylabel("season")
plt.show()
