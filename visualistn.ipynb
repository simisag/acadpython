# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
w=pd.read_csv("C:\\Users\\acer\\Desktop\\machine\\weather.csv")

# %%
w.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
c=w.corr()
sns.heatmap(c)

# %%
plt.plot(w["MinTemp"])

# %%
plt.scatter(x='MinTemp',y='Rainfall',data=w)
plt.xlabel("Min Temp")
plt.ylabel("Rainfall")
# Out:
# Text(0,0.5,'Rainfall')

# %%
sns.lmplot(x="MinTemp",y="Rainfall",data=w)

# %%
plt.hist(w["Rainfall"])
plt.xlabel("Rainfall")
# Out:
# Text(0.5,0,'Rainfall')

# %%
w.fillna(w.mean(),inplace=True)
sns.distplot(w["WindGustSpeed"],kde=True)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(w["WindGustSpeed"],shade=True,color="r")

# %%
sns.kdeplot(w['Temp9am'], w['Temp3pm'])

# %%
sns.jointplot(w['Temp9am'], w['Temp3pm'],kind='hex',color='r')
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\acer\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(w['Temp9am'], w['Temp3pm'],color='r',kind='kde')

# %%
plt.figure(figsize=(10,10))
sns.countplot(x="WindDir9am",data=w)

# %%
sns.pairplot(w)

# %%
plt.hist(w['Humidity9am'])
# Out:
# (array([ 4., 16., 16., 38., 48., 78., 73., 40., 29., 24.]),
#  array([36. , 42.3, 48.6, 54.9, 61.2, 67.5, 73.8, 80.1, 86.4, 92.7, 99. ]),
#  <a list of 10 Patch objects>)
